# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../src/data/zillow_data.csv')

# %%
df.shape
# Out:
# (14723, 272)

# %%
df.head(2)
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
#
# [2 rows x 272 columns]

# %%
def get_datetimes(df):
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')

# %%
def melt_data(df):
    melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted

# %%
df_lf = melt_data(df)

# %%
df_lf.shape
# Out:
# (3744704, 9)

# %%
df_lf[df_lf.RegionName == 79936]
# Out:
#          RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# 4           93144       79936  El Paso    TX  El Paso    El Paso         5
# 14727       93144       79936  El Paso    TX  El Paso    El Paso         5
# 29450       93144       79936  El Paso    TX  El Paso    El Paso         5
# 44173       93144       79936  El Paso    TX  El Paso    El Paso         5
# 58896       93144       79936  El Paso    TX  El Paso    El Paso         5
# ...           ...         ...      ...   ...      ...        ...       ...
# 3827984     93144       79936  El Paso    TX  El Paso    El Paso         5
# 3842707     93144       79936  El Paso    TX  El Paso    El Paso         5
# 3857430     93144       79936  El Paso    TX  El Paso    El Paso         5
# 3872153     93144       79936  El Paso    TX  El Paso    El Paso         5
# 3886876     93144       79936  El Paso    TX  El Paso    El Paso         5
#
#               time     value
# 4       1996-04-01   77300.0
# 14727   1996-05-01   77300.0
# 29450   1996-06-01   77300.0
# 44173   1996-07-01   77300.0
# 58896   1996-08-01   77400.0
# ...            ...       ...
# 3827984 2017-12-01  120300.0
# 3842707 2018-01-01  120300.0
# 3857430 2018-02-01  120500.0
# 3872153 2018-03-01  121000.0
# 3886876 2018-04-01  121500.0
#
# [265 rows x 9 columns]

# %%
df_lf[df_lf.SizeRank == 2]
# Out:
#          RegionID  RegionName      City State              Metro CountyName  \
# 1           90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 14724       90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 29447       90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 44170       90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 58893       90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# ...           ...         ...       ...   ...                ...        ...
# 3827981     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 3842704     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 3857427     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 3872150     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 3886873     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
#
#          SizeRank       time     value
# 1               2 1996-04-01  235700.0
# 14724           2 1996-05-01  236900.0
# 29447           2 1996-06-01  236700.0
# 44170           2 1996-07-01  235400.0
# 58893           2 1996-08-01  233300.0
# ...           ...        ...       ...
# 3827981         2 2017-12-01  316600.0
# 3842704         2 2018-01-01  318100.0
# 3857427         2 2018-02-01  319600.0
# 3872150         2 2018-03-01  321100.0
# 3886873         2 2018-04-01  321800.0
#
# [265 rows x 9 columns]

# %%
df[df.RegionName == 79936]
# Out:
#    RegionID  RegionName     City State    Metro CountyName  SizeRank  1996-04  \
# 4     93144       79936  El Paso    TX  El Paso    El Paso         5  77300.0
#
#    1996-05  1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 4  77300.0  77300.0  ...   119100   119400   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04
# 4   120300   120300   120500   121000   121500
#
# [1 rows x 272 columns]
